# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# !pip install twython
# !pip install nltk

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
consumer_key = 'RNLHyNUdnxSzs8kh6hsxR3MRa'
consumer_secret = 'XrSgN8nP8PAsa4MnLEa0ueW89izsP0Q0dnVbd5aU7RDweECECY'
access_token = '1075013363439042560-eSoZ5zqXhXl3sgzKZRkBOWe4AwNqpO'
access_token_secret = 'FMLXBu2KVYmSN47Nb7l8Jm1pPzh0oGHvUH4VVla6152el'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Artificial Intelligence', count=200)

data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))

print(tweets[14].created_at)
# Out:
#                                               Tweets
# 0  RT @RadiologyACR: New commentary explores why ...
# 1  Using Artificial Intelligence To Change the Wa...
# 2  How Artificial Intelligence and Digital Transf...
# 3  @jitterbit @simonlpeel Simon gets very real ab...
# 4  "[...] contemporary forms of artificial intell...
# 5  “If our children are educated by AI teachers, ...
# 6  RT @evankirstel: What Pioneering Enterprises A...
# 7  RT @YALIRLCEA: Emotional Intelligence is what ...
# 8  Ten HR Trends In The Age Of Artificial Intelli...
# 9  Maybe it is time for a new approach...go have ...
# 2019-01-30 15:47:03

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()

listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['Polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @RadiologyACR: New commentary explores why ...
# 1   Using Artificial Intelligence To Change the Wa...
# 2   How Artificial Intelligence and Digital Transf...
# 3   @jitterbit @simonlpeel Simon gets very real ab...
# 4   "[...] contemporary forms of artificial intell...
# 5   “If our children are educated by AI teachers, ...
# 6   RT @evankirstel: What Pioneering Enterprises A...
# 7   RT @YALIRLCEA: Emotional Intelligence is what ...
# 8   Ten HR Trends In The Age Of Artificial Intelli...
# 9   Maybe it is time for a new approach...go have ...
# 10  Robots and machines do not have basic human qu...
# 11  RT @antgrasso: Where will AI play? Artificial ...
# 12  RT @Chellaney: The linkage between high-speed ...
# 13  RT @CNN: London's Gatwick Airport is testing o...
# 14  RT @verge: Porn: you know it when you see it, ...
# 15  RT @Chellaney: The linkage between high-speed ...
# ...
